# %%
import pandas as pd

# %%
opdf = pd.read_csv('Options/gold-options_03_30_2017.csv')

# %%
opdf.head()
# Out:
#    Trade Date Product Code Product Type Underlying Product Code Put/Call  \
# 0    20170330           OG            O                      GC        C
# 1    20170330           OG            O                      GC        C
# 2    20170330           OG            O                      GC        C
# 3    20170330           OG            O                      GC        C
# 4    20170330           OG            O                      GC        C
#
#    Strike Price  Contract Year  Contract Month  Contract Day  Settlement  \
# 0          1050           2017               5             0       198.0
# 1          1100           2017               5             0       148.0
# 2          1125           2017               5             0       123.1
# 3          1135           2017               5             0       113.1
# 4          1140           2017               5             0       108.2
#
#    Open Interest  Total Volume  Globex Open Price  Globex High Price  \
# ...

# %%
opdf['Trade Date'] = 20170331

# begin = datetime.date(2017,1,1)
# end = datetime.date(2017,12,31)
# for i in range((end - begin).days+1):
#     opdf = pd.read_csv('Options/gold-options_03_30_2017.csv')
#     opdf['Trade Date'] = begin + i + 1

# %%
# Out:
# 0       20170331
# 1       20170331
# 2       20170331
# 3       20170331
# 4       20170331
# 5       20170331
# 6       20170331
# 7       20170331
# 8       20170331
# 9       20170331
# 10      20170331
# 11      20170331
# 12      20170331
# 13      20170331
# 14      20170331
# 15      20170331
# 16      20170331
# 17      20170331
# 18      20170331
# 19      20170331
# 20      20170331
# 21      20170331
# 22      20170331
# 23      20170331
# 24      20170331
# 25      20170331
# 26      20170331
# 27      20170331
# 28      20170331
# 29      20170331
#           ...
# 1605    20170331
# 1606    20170331
# 1607    20170331
# 1608    20170331
# 1609    20170331
# 1610    20170331
# 1611    20170331
# 1612    20170331
# 1613    20170331
# 1614    20170331
# 1615    20170331
# 1616    20170331
# 1617    20170331
# 1618    20170331
# 1619    20170331
# 1620    20170331
# 1621    20170331
# 1622    20170331
# 1623    20170331
# 1624    20170331
# 1625    20170331
# ...
